# %%
import csv
import random
import time

ligne=1000
fieldnames=['Landing Page URL ID','Referrer URL','Impression ID','Asset ID','Active View: Eligible Impressions',
            'Active View: Measurable Impressions','Active View: Viewable Impressions','Activity ID','Event Time',
            'Event Type','Event Sub-Type','User ID','Advertiser ID', 'Campaign ID', 'Floodlight Configuration',
            'Ad ID','Rendering ID','Creative Version','Site ID (DCM)','Placement ID','State/Region','Browser/Platform ID','Browser/Platform Version','Operating System ID','Designated Market Area (DMA) ID',
            'City ID','Conversion ID','Segment Value 1','Rich Media Event ID','Rich Media Event Type ID','Total Conversions', 'Event Counters',
            'DBM Request Time','DBM Advertiser ID','DBM Insertion Order ID','DBM Line Item ID','DBM Campaign ID',
            'DBM Creative ID','DBM Bid Price (USD)','DBM Bid Price (Partner Currency)','DBM Bid Price (Advertiser Currency)',
            'DBM Site ID','DBM Exchange ID','DBM Attributed Inventory Source Is Public','DBM Ad Position','DBM Designated Market Area (DMA) ID', 
            'DBM State/Region ID','DBM City ID','DBM Operating System ID','DBM Browser/Platform ID','DBM Browser Timezone Offset Minutes',
            'DBM Net Speed','DBM ISP ID','DBM Device Type','DBM Mobile Make ID','DBM Mobile Model ID','DBM Media Cost (USD)',
            'DBM Media Cost (Partner Currency)','DBM Media Cost (Advertiser Currency)','DBM Revenue (USD)','DBM Revenue (Partner Currency)',
            'DBM Revenue (Advertiser Currency)','DBM Total Media Cost (USD)','DBM Total Media Cost (Partner Currency)','DBM Total Media Cost (Advertiser Currency)',
            'DBM CPM Fee 1 (USD)', 'DBM CPM Fee 1 (Partner Currency)','DBM CPM Fee 1 (Advertiser Currency)','DBM CPM Fee 2 (USD)','DBM CPM Fee 2 (Partner Currency)',
            'DBM CPM Fee 2 (Advertiser Currency)','DBM CPM Fee 3 (USD)','DBM CPM Fee 3 (Partner Currency)','DBM CPM Fee 3 (Advertiser Currency)',
            'DBM CPM Fee 4 (USD)','DBM CPM Fee 4 (Partner Currency)','DBM CPM Fee 4 (Advertiser Currency)','DBM CPM Fee 5 (USD)',
            'DBM CPM Fee 5 (Partner Currency)','DBM CPM Fee 5 (Advertiser Currency)','DBM Media Fee 1 (USD)','DBM Media Fee 1 (Partner Currency)',
            'DBM Media Fee 1 (Advertiser Currency)','DBM Media Fee 2 (USD)','DBM Media Fee 2 (Partner Currency)','DBM Media Fee 2 (Advertiser Currency)',
            'DBM Media Fee 3 (USD)','DBM Media Fee 3 (Partner Currency)','DBM Media Fee 3 (Advertiser Currency)','DBM Media Fee 4 (USD)',
            'DBM Media Fee 4 (Partner Currency)','DBM Media Fee 4 (Advertiser Currency)','DBM Media Fee 5 (USD)','DBM Media Fee 5 (Partner Currency)',
            'DBM Media Fee 5 (Advertiser Currency)','DBM Data Fees (USD)','DBM Data Fees (Partner Currency)','DBM Data Fees (Advertiser Currency)',
            'DBM Billable Cost (USD)','DBM Billable Cost (Partner Currency)','DBM Billable Cost (Advertiser Currency)']
writer = csv.DictWriter(open("DoubleClick.csv", "w"), fieldnames=fieldnames)

Event_Type=['VIEW', 'CLICK', 'CONVERSION', 'NULL']
Event_Sub_Type=['VIEW', 'CLICK', 'POSTVIEW','POSTCLICK', 'NULL']
DBM_Attributed_Inventory_Source_Is_Public = ['TRUE', 'FALSE']
URL=['https://www.amazon.fr/', 'https://www.cdiscount.com/', 'https://fr.aliexpress.com/', 'https://shopping.google.fr/']
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

Browser_version=['Google Chrome','Mozilla Firefox','Opera','Microsoft Edge','Vivaldi','Brave Browser','Maxthon',
                 'UR Browser','Sushi Browser','Waterfox','Torch Browser','UC Browser','Safari']
writer.writerow(dict(zip(fieldnames, fieldnames)))
for i in range(0, ligne):
  writer.writerow(dict([

    ('Landing Page URL ID', "ID" + str(i)),
    ('Referrer URL', random.choice(URL)),
    ('Impression ID', 'impr : ' + random.choice(str(random.sample(range(10000000), 1000)))),
    ('Asset ID', random.choice(random.sample(range(10000000), 10000))),
    ('Active View: Eligible Impressions', random.choice(random.sample(range(10000000), 10000))),
    ('Active View: Measurable Impressions', random.choice(random.sample(range(10000000), 10000))),
    ('Active View: Viewable Impressions', random.choice(random.sample(range(10000000), 10000))),
    ('Activity ID', random.choice(random.sample(range(10000000), 10000))),
    ('Event Time', round(time.time() * 1000)),
    ('Event Type', random.choice(Event_Type)),
    ('Event Sub-Type', random.choice(random.sample(range(10000000), 10000))),
    ('User ID', "USER_ID" + str(random.choice(str(random.sample(range(10000000), 1000))))),
    ('Advertiser ID', random.choice(random.sample(range(10000000), 10000))),
    ('Campaign ID', random.choice(random.sample(range(10000000), 10000))),
    ('Floodlight Configuration', random.choice(random.sample(range(10000000), 10000))),
    ('Ad ID', random.choice(random.sample(range(10000000), 10000))),
    ('Rendering ID', random.choice(random.sample(range(10000000), 10000))),
    ('Creative Version', random.choice(random.sample(range(10000), 1))),
    ('Site ID (DCM)', random.choice(random.sample(range(10000000), 10000))),
    ('Placement ID', random.choice(random.sample(range(10000000), 10000))),
    ('State/Region', random.choice(states)),
    ('Browser/Platform Version', random.choice(Browser_version)),
     
    ('Browser/Platform ID', random.choice(random.sample(range(10000000), 10000))),
    ('Operating System ID', random.choice(random.sample(range(10000000), 10000))),
    ('Designated Market Area (DMA) ID', random.choice(random.sample(range(10000000), 10000))),
    ('City ID', random.choice(random.sample(range(10000000), 10000))),
      
    ('Conversion ID', random.choice(random.sample(range(2), 1))),
    ('Segment Value 1', random.choice(random.sample(range(10000000), 10000))),
    ('Rich Media Event ID', random.choice(random.sample(range(10000000), 10000))),
    ('Rich Media Event Type ID', random.choice(random.sample(range(10000000), 10000))),
      
    ('Total Conversions', "qty="  + random.choice(str(random.sample(range(10000), 1)))),
        
    ('Event Counters', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Request Time', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Advertiser ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Insertion Order ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Line Item ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Campaign ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Creative ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Bid Price (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Bid Price (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Bid Price (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Site ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Exchange ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Attributed Inventory Source Is Public', random.choice(DBM_Attributed_Inventory_Source_Is_Public)),
    ('DBM Ad Position', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Designated Market Area (DMA) ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM State/Region ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM State/Region ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM City ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Operating System ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Browser/Platform ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Browser Timezone Offset Minutes', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Net Speed', random.choice(random.sample(range(10000000), 10000))),
    ('DBM ISP ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Device Type', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Mobile Make ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Mobile Model ID', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Cost (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Revenue (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Cost (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Revenue (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Revenue (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 1 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Total Media Cost (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Total Media Cost (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Total Media Cost (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 1 (USD)', random.choice(random.sample(range(10000), 1))),
    ('DBM CPM Fee 1 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 1 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 2 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 2 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 2 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 3 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 3 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 3 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 4 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 4 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 4 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 5 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 1 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM CPM Fee 5 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 1 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 1 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 1 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 2 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 2 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 2 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),  
    ('DBM Media Fee 3 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 3 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 3 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 4 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 4 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 4 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 5 (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 5 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Media Fee 5 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Data Fees (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Data Fees (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Data Fees (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Billable Cost (USD)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Billable Cost (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
    ('DBM Billable Cost (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
  ]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-b85ec94893a4> in <module>
#     117     ('DBM CPM Fee 1 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
#     118     ('DBM CPM Fee 2 (USD)', random.choice(random.sample(range(10000000), 10000))),
# --> 119     ('DBM CPM Fee 2 (Partner Currency)', random.choice(random.sample(range(10000000), 10000))),
#     120     ('DBM CPM Fee 2 (Advertiser Currency)', random.choice(random.sample(range(10000000), 10000))),
#     121     ('DBM CPM Fee 3 (USD)', random.choice(random.sample(range(10000000), 10000))),
#
# ~/anaconda3/lib/python3.8/random.py in sample(self, population, k)
#     381                     j = randbelow(n)
#     382                 selected_add(j)
# --> 383                 result[i] = population[j]
#     384         return result
#     385
#
# KeyboardInterrupt:
